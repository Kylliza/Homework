# %% [markdown]
# # <font color=blue>*Homework #4.*

# %% [markdown]
# 1. What does one need to do to use a module?
#
#     *We need to use the import statement and the name of the module we want to import.*

# %% [markdown]
# 2. Name a Module (not the DateTime Nodule) we looked at and write a line or 2 of code as an example using this module.
#
#     *Numpy*

# %%
#import numpy as np #man...my numpy import is not working in vs code...

#no other imports works for me...just datetime

import math

print(math.ceil(1.1))
# Out:
# 2

# %% [markdown]
# 3. What is a benefit of using Exception handling?
#
#     *You can try your code and check for errors / bugs before actually executing it on the code itself.*

# %% [markdown]
# 4. NumPy arrays are like what Python data type?
#
#     &#10148; i - integer
#
#     &#10148; b - boolean
#
#     &#10148; u - unsigned interger
#
#     &#10148; f - float
#
#     &#10148; c - complex float
#
#     &#10148; m - timedelta
#
#     &#10148; M - datetime
#
#     &#10148; O - object

# %% [markdown]
# What is one of the main benefits of using NumPy arrays?
#
# *Numpy arrays are faster and more compact than Python lists. It uses less memory and provides a mechanism of specifying the data types.*

# %% [markdown]
# What is one of the main requirements about the 'dtype' of NumPy arrays?
#
# *It must be consistent for all the elements withing the array.*

# %% [markdown]
# Of the 10 uses of NumPy, name 2.
#
# * *Arithmetic Operations*
# * *Stacking*

# %% [markdown]
# Name one of the other libraries we'll use with NumPy?
#
# *Beutiful Soup*

# %% [markdown]
# What is the shape of NumPy arrays?
#
# * *Vector* 1d
# * *Matrix* 2d
# ![image.png](attachment:image.png)
# The Matrix lulz
# * *Tensor* 3d +

# %% [markdown]
# What is a tensor?
#
# *Tensor == an array with 3+ dimensions*

# %% [markdown]
# Name a reason why it's better using  NumPy for Data Analysis than using a Python List?
#
# *It takes less time with NumPy (memory wise) than using lists.*

# %% [markdown]
# When creating an "empty" array, where do the elements come from?
#
# *The function empty creates an array whose initial content is random and depends on the state of the memory. We fill the elements when creating empty arrays.*

# %%
# 1. Use the DateTime module to get Current Date and Time,
# and save it to a variable. Then extract just the 
# Full month name from that variable.

import datetime as dt

today = dt.datetime.today()
print('Today''s'' date is' , today)

month = dt.datetime.today()

print("Month is", month.strftime("%B"))
# Out:
# Todays date is 2023-02-20 10:36:39.201948
# Month is February

# %%
# 2. Write a simple function that takes 2 parameters -- a  first name and a day name.
#     - Set a default value for the day name of Sunday.
#     - Have the function print out a greeting -- using the parameters -- that says something like "Hi first-name! Happy day-name!". Remember to use the variables in the greeting to replace first-name and day-name.  
#     - Invoke this function with 2 variables.
#     - Invoke this function with 1 variable only.


def greet(fn, dn = 'Sunday'):
    print('Hi ' + fn + '! Happy ' + dn + '!')


greet('Alexis', 'Sunday')
greet('Alexis', 'holiday')

#couldn't find a way to print just Hi Alexis!..........
# Out:
# Hi Alexis! Happy Sunday!
# Hi Alexis! Happy holiday!

# %%
#3. Import NumPy, use one of the NumPy methods 
# and create an array with a shape of ... 
# (2, 3, 2). You can use the reshape method -- `.reshape()`

#will try the code, but I never got numpy library to work with 
# my VS code. Will use online python compiler to 
# run my code and verify if its gud. 

import numpy as np

array1 = np.arange(12)
reshape = np.reshape(array1, (2,3,2))

print(reshape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[71], line 9
#       1 #3. Import NumPy, use one of the NumPy methods
#       2 # and create an array with a shape of ...
#       3 # (2, 3, 2). You can use the reshape method -- `.reshape()`
#    (...)
#       6 # Will use online python compiler to run my code and verify
#       7 #if its gud.
# ----> 9 import numpy as np
#      11 array1 = np.arange(12)
#      12 reshape = np.reshape(array1, (2,3,2))
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#4. Use NumPy `.linspace()` to create an array with 6 
#   linearly spaced values between 0 and 20

import numpy as np 

lin = np.linspace(0, 20, num=6)

print("Array lin ", lin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 4
#       1 #Use NumPy `.linspace()` to create an array with 6
#       2 # linearly spaced values between 0 and 20
# ----> 4 lin = np.linspace(0, 3, 6, 7, 8, 20,)
#       6 print("Array lin ", lin)
#
# NameError: name 'np' is not defined

# %%
#5. Make a Deep Copy of the above array you created.

import copy 

lin2 = copy.deepcopy(lin)

print('This is a deep copy ', lin2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 5
#       1 #Make a Deep Copy of the above array you created.
#       3 import copy
# ----> 5 lin2 = copy.deepcopy(lin)
#       7 print('This is a deep copy ', lin2)
#
# NameError: name 'lin' is not defined

# %% [markdown]
# 6. What are 2 reasons we use NumPy arrays over Python Lists
#
# * *NumPy arrays are faster and more compact than Python lists*
# * *NumPy arrays provide a wide range of built-in mathematical functions and operations that are optimized for numerical computations*
